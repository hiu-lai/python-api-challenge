# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"
cities_csv = pd.read_csv(output_data_file)

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
#     print(city)
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

print("Beginning Data Retrieval")
print("-------------------------")
i = 0
valid_cities = []
for city in cities:
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    try:
        response = requests.get(query_url).json()
        testcon = response['clouds']['all']
        i = i + 1
        iset = int(i/50) + 1
        cityid = i - ((iset - 1) * 50)
        print(f"Processing Record {cityid} of Set {iset} | {city}")
        valid_cities.append(city)
    except (KeyError, IndexError):
        print("City not found. Skipping...")
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | coos bay
# Processing Record 4 of Set 1 | half moon bay
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | jamestown
# City not found. Skipping...
# Processing Record 8 of Set 1 | basco
# City not found. Skipping...
# Processing Record 9 of Set 1 | saldanha
# Processing Record 10 of Set 1 | barrow
# City not found. Skipping...
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | bianzhuang
# Processing Record 15 of Set 1 | auki
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | katsuura
# Processing Record 19 of Set 1 | turayf
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | stendal
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | thompson
# Processing Record 24 of Set 1 | mao
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | ugoofaaru
# Processing Record 27 of Set 1 | concepcion del uruguay
# Processing Record 28 of Set 1 | waipawa
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | meulaboh
# Processing Record 31 of Set 1 | ayan
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | inyonga
# Processing Record 34 of Set 1 | pangnirtung
# Processing Record 35 of Set 1 | lagoa
# Processing Record 36 of Set 1 | normandin
# Processing Record 37 of Set 1 | nizhnevartovsk
# Processing Record 38 of Set 1 | zhigansk
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | butaritari
# City not found. Skipping...
# Processing Record 41 of Set 1 | saint-georges
# Processing Record 42 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 43 of Set 1 | saint george
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | poum
# Processing Record 46 of Set 1 | marsh harbour
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | singaparna
# Processing Record 49 of Set 1 | bhadrachalam
# Processing Record 0 of Set 2 | vaini
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | emborion
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | tortoli
# Processing Record 44 of Set 4 | juneau
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | praia
# Processing Record 47 of Set 4 | gizo
# Processing Record 48 of Set 4 | balikpapan
# Processing Record 49 of Set 4 | belyy yar
# Processing Record 0 of Set 5 | saint-augustin
# Processing Record 1 of Set 5 | domna
# Processing Record 2 of Set 5 | amapa
# Processing Record 3 of Set 5 | udachnyy
# Processing Record 4 of Set 5 | karaidel
# Processing Record 5 of Set 5 | bethel
# Processing Record 6 of Set 5 | bani walid
# Processing Record 7 of Set 5 | ippy
# Processing Record 8 of Set 5 | todos santos
# Processing Record 9 of Set 5 | usagara
# Processing Record 10 of Set 5 | raga
# Processing Record 11 of Set 5 | la ronge
# Processing Record 12 of Set 5 | vardo
# Processing Record 13 of Set 5 | tanggu
# Processing Record 14 of Set 5 | santa luzia
# Processing Record 15 of Set 5 | ostrovnoy
# Processing Record 16 of Set 5 | broken hill
# Processing Record 17 of Set 5 | general roca
# Processing Record 18 of Set 5 | nome
# Processing Record 19 of Set 5 | nampula
# Processing Record 20 of Set 5 | komsomolskiy
# Processing Record 21 of Set 5 | new norfolk
# Processing Record 22 of Set 5 | cairns
# Processing Record 23 of Set 5 | jose bonifacio
# Processing Record 24 of Set 5 | pacific grove
# Processing Record 25 of Set 5 | salinopolis
# Processing Record 26 of Set 5 | luebo
# Processing Record 27 of Set 5 | imbituba
# City not found. Skipping...
# Processing Record 28 of Set 5 | touros
# Processing Record 29 of Set 5 | hibbing
# Processing Record 30 of Set 5 | bosaso
# Processing Record 31 of Set 5 | miyako
# Processing Record 32 of Set 5 | fortuna
# City not found. Skipping...
# Processing Record 33 of Set 5 | longyearbyen
# Processing Record 34 of Set 5 | ola
# Processing Record 35 of Set 5 | havelock
# Processing Record 36 of Set 5 | taltal
# Processing Record 37 of Set 5 | majene
# Processing Record 38 of Set 5 | mehamn
# Processing Record 39 of Set 5 | dingle
# Processing Record 40 of Set 5 | lundazi
# Processing Record 41 of Set 5 | foca
# Processing Record 42 of Set 5 | ozu
# Processing Record 43 of Set 5 | quelimane
# Processing Record 44 of Set 5 | tommot
# Processing Record 45 of Set 5 | carnarvon
# Processing Record 46 of Set 5 | santa cruz cabralia
# Processing Record 47 of Set 5 | port elizabeth
# Processing Record 48 of Set 5 | nador
# Processing Record 49 of Set 5 | lavrentiya
# Processing Record 0 of Set 6 | cabo rojo
# Processing Record 1 of Set 6 | tuatapere
# Processing Record 2 of Set 6 | hovd
# Processing Record 3 of Set 6 | isangel
# Processing Record 4 of Set 6 | vanimo
# Processing Record 5 of Set 6 | comodoro rivadavia
# Processing Record 6 of Set 6 | bayan
# Processing Record 7 of Set 6 | sao jose da coroa grande
# Processing Record 8 of Set 6 | darhan
# Processing Record 9 of Set 6 | caucaia
# Processing Record 10 of Set 6 | tasiilaq
# Processing Record 11 of Set 6 | soyo
# Processing Record 12 of Set 6 | binzhou
# Processing Record 13 of Set 6 | arraial do cabo
# Processing Record 14 of Set 6 | mogwase
# Processing Record 15 of Set 6 | svetlogorsk
# Processing Record 16 of Set 6 | san rafael
# Processing Record 17 of Set 6 | wufeng
# Processing Record 18 of Set 6 | inta
# Processing Record 19 of Set 6 | batemans bay
# Processing Record 20 of Set 6 | najran
# Processing Record 21 of Set 6 | bathsheba
# Processing Record 22 of Set 6 | kruisfontein
# Processing Record 23 of Set 6 | nakapiripirit
# Processing Record 24 of Set 6 | matadi
# Processing Record 25 of Set 6 | tiksi
# Processing Record 26 of Set 6 | morden
# Processing Record 27 of Set 6 | konevo
# Processing Record 28 of Set 6 | santa maria
# City not found. Skipping...
# Processing Record 29 of Set 6 | monrovia
# Processing Record 30 of Set 6 | airai
# Processing Record 31 of Set 6 | kaitangata
# Processing Record 32 of Set 6 | kungurtug
# Processing Record 33 of Set 6 | crossville
# Processing Record 34 of Set 6 | vestmannaeyjar
# Processing Record 35 of Set 6 | atbasar
# Processing Record 36 of Set 6 | laiyang
# City not found. Skipping...
# Processing Record 37 of Set 6 | umm kaddadah
# Processing Record 38 of Set 6 | springfield
# Processing Record 39 of Set 6 | beringovskiy
# Processing Record 40 of Set 6 | westport
# Processing Record 41 of Set 6 | suntar
# Processing Record 42 of Set 6 | yar-sale
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | jinxiang
# City not found. Skipping...
# Processing Record 45 of Set 6 | roseburg
# Processing Record 46 of Set 6 | great yarmouth
# Processing Record 47 of Set 6 | lesnoye
# Processing Record 48 of Set 6 | le port
# Processing Record 49 of Set 6 | porto walter
# City not found. Skipping...
# Processing Record 0 of Set 7 | zhangye
# Processing Record 1 of Set 7 | gat
# Processing Record 2 of Set 7 | kavaratti
# Processing Record 3 of Set 7 | punto fijo
# Processing Record 4 of Set 7 | ivanovka
# Processing Record 5 of Set 7 | sharan
# Processing Record 6 of Set 7 | faya
# Processing Record 7 of Set 7 | sao domingos
# Processing Record 8 of Set 7 | padilla
# Processing Record 9 of Set 7 | myitkyina
# Processing Record 10 of Set 7 | bodden town
# Processing Record 11 of Set 7 | nizhnyaya omka
# Processing Record 12 of Set 7 | aswan
# City not found. Skipping...
# Processing Record 13 of Set 7 | mount gambier
# Processing Record 14 of Set 7 | hachinohe
# Processing Record 15 of Set 7 | providencia
# Processing Record 16 of Set 7 | lingao
# Processing Record 17 of Set 7 | chokurdakh
# Processing Record 18 of Set 7 | luau
# City not found. Skipping...
# Processing Record 19 of Set 7 | castro marim
# Processing Record 20 of Set 7 | victoria
# Processing Record 21 of Set 7 | honiara
# Processing Record 22 of Set 7 | vanavara
# Processing Record 23 of Set 7 | sri aman
# Processing Record 24 of Set 7 | staraya poltavka
# Processing Record 25 of Set 7 | jalu
# Processing Record 26 of Set 7 | igarka
# Processing Record 27 of Set 7 | waounde
# Processing Record 28 of Set 7 | sur
# Processing Record 29 of Set 7 | canmore
# Processing Record 30 of Set 7 | grand-lahou
# City not found. Skipping...
# Processing Record 19 of Set 10 | beyneu
# Processing Record 20 of Set 10 | nova olinda do norte
# Processing Record 21 of Set 10 | san patricio
# Processing Record 22 of Set 10 | kuching
# Processing Record 23 of Set 10 | kashi
# Processing Record 24 of Set 10 | syracuse
# Processing Record 25 of Set 10 | temple
# Processing Record 26 of Set 10 | grevena
# City not found. Skipping...
# Processing Record 27 of Set 10 | tecoanapa
# Processing Record 28 of Set 10 | turukhansk
# City not found. Skipping...
# Processing Record 29 of Set 10 | lake city
# Processing Record 30 of Set 10 | noumea
# Processing Record 31 of Set 10 | rio gallegos
# City not found. Skipping...
# Processing Record 32 of Set 10 | weinan
# Processing Record 33 of Set 10 | nhulunbuy
# Processing Record 34 of Set 10 | dalbandin
# Processing Record 35 of Set 10 | hirado
# Processing Record 36 of Set 10 | cangucu
# Processing Record 37 of Set 10 | phan thiet
# Processing Record 38 of Set 10 | ballina
# Processing Record 39 of Set 10 | hegang
# Processing Record 40 of Set 10 | palana
# Processing Record 41 of Set 10 | viransehir
# Processing Record 42 of Set 10 | ariquemes
# Processing Record 43 of Set 10 | puerto pailas
# Processing Record 44 of Set 10 | palmer
# Processing Record 45 of Set 10 | yatou
# Processing Record 46 of Set 10 | madaoua
# Processing Record 47 of Set 10 | pisco
# Processing Record 48 of Set 10 | kalmunai
# Processing Record 49 of Set 10 | conceicao do araguaia
# City not found. Skipping...
# Processing Record 0 of Set 11 | henties bay
# Processing Record 1 of Set 11 | vila do maio
# Processing Record 2 of Set 11 | keuruu
# Processing Record 3 of Set 11 | moshi
# Processing Record 4 of Set 11 | rafai
# Processing Record 5 of Set 11 | paraiso
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 11 | sinop
# Processing Record 7 of Set 11 | karonga
# Processing Record 8 of Set 11 | nantucket
# Processing Record 9 of Set 11 | puerto colombia
# Processing Record 10 of Set 11 | baykit
# Processing Record 11 of Set 11 | seymchan
# Processing Record 12 of Set 11 | hobyo
# Processing Record 13 of Set 11 | agirish
# Processing Record 14 of Set 11 | malmesbury
# Processing Record 15 of Set 11 | namatanai
# Processing Record 16 of Set 11 | banon
# Processing Record 17 of Set 11 | abha
# Processing Record 18 of Set 11 | geraldton
# Processing Record 19 of Set 11 | bonfim
# Processing Record 20 of Set 11 | beaune
# Processing Record 21 of Set 11 | riverton
# Processing Record 22 of Set 11 | saint-louis
# Processing Record 23 of Set 11 | vung tau
# Processing Record 24 of Set 11 | wangaratta
# Processing Record 25 of Set 11 | oistins
# Processing Record 26 of Set 11 | las vegas
# Processing Record 27 of Set 11 | hohhot
# Processing Record 28 of Set 11 | honningsvag
# Processing Record 29 of Set 11 | kampot
# Processing Record 30 of Set 11 | pangody
# Processing Record 31 of Set 11 | tangzhai
# Processing Record 32 of Set 11 | muzhi
# Processing Record 33 of Set 11 | katete
# Processing Record 34 of Set 11 | taoudenni
# Processing Record 35 of Set 11 | hun
# City not found. Skipping...
# Processing Record 36 of Set 11 | mount isa
# Processing Record 37 of Set 11 | bandarbeyla
# Processing Record 38 of Set 11 | deniliquin
# Processing Record 39 of Set 11 | iki-burul
# Processing Record 40 of Set 11 | bumba
# Processing Record 41 of Set 11 | ambanja
# Processing Record 42 of Set 11 | agadir
# Processing Record 43 of Set 11 | kargasok
# Processing Record 44 of Set 11 | pavlovsk
# Processing Record 45 of Set 11 | dwarka
# Processing Record 46 of Set 11 | sakakah
# Processing Record 47 of Set 11 | atar
# Processing Record 48 of Set 11 | adre
# Processing Record 49 of Set 11 | marfino
# Processing Record 0 of Set 12 | coihaique
# Processing Record 1 of Set 12 | chapais
# Processing Record 2 of Set 12 | kathmandu
# Processing Record 3 of Set 12 | kita
# Processing Record 4 of Set 12 | aksu
# Processing Record 5 of Set 12 | kawalu
# Processing Record 6 of Set 12 | belmonte
# Processing Record 7 of Set 12 | naze
# Processing Record 8 of Set 12 | key west
# Processing Record 9 of Set 12 | parabel
# Processing Record 10 of Set 12 | havre-saint-pierre
# Processing Record 11 of Set 12 | charters towers
# Processing Record 12 of Set 12 | avera
# Processing Record 13 of Set 12 | dicabisagan
# Processing Record 14 of Set 12 | baran
# Processing Record 15 of Set 12 | mpika
# Processing Record 16 of Set 12 | wanning
# Processing Record 17 of Set 12 | coquimbo
# Processing Record 18 of Set 12 | clyde river
# Processing Record 19 of Set 12 | bolshevik
# Processing Record 20 of Set 12 | laerdalsoyri
# Processing Record 21 of Set 12 | nalut
# Processing Record 22 of Set 12 | los negros
# Processing Record 23 of Set 12 | tandalti
# Processing Record 24 of Set 12 | luena
# Processing Record 25 of Set 12 | teguise
# Processing Record 26 of Set 12 | porto novo
# Processing Record 27 of Set 12 | asosa
# Processing Record 28 of Set 12 | leh
# Processing Record 29 of Set 12 | phibun mangsahan
# Processing Record 30 of Set 12 | edendale
# Processing Record 31 of Set 12 | niamey
# Processing Record 32 of Set 12 | beloha
# Processing Record 33 of Set 12 | jilib
# Processing Record 34 of Set 12 | bafra
# Processing Record 35 of Set 12 | ngunguru
# Processing Record 36 of Set 12 | aripuana
# Processing Record 37 of Set 12 | arman
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Loading valid cities into dataframe
city_pd = pd.DataFrame({'city': valid_cities})

city_pd['Lat'] = ""
city_pd['Lng'] = ""
city_pd['Max Temp'] = ""
city_pd['Humidity'] = ""
city_pd['Cloudiness'] = ""
city_pd['Wind Speed'] = ""
city_pd['Country'] = ""
city_pd['Date'] = ""

# ============ TEST DATA =========
# city = "okha"
# query_url = url + "appid=" + weather_api_key + "&q=" + city
# requests.get(query_url).json()
# ================================

for index, row in city_pd.iterrows():
    city = row['city']
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    city_pd.loc[index, 'Lat'] = response['coord']['lat']
    city_pd.loc[index, 'Lng'] = response['coord']['lon']
    city_pd.loc[index, 'Max Temp'] = response['main']['temp_max']
    city_pd.loc[index, 'Humidity'] = response['main']['humidity']
    city_pd.loc[index, 'Cloudiness'] = response['clouds']['all']
    city_pd.loc[index, 'Wind Speed'] = response['wind']['speed']
    city_pd.loc[index, 'Country'] = response['sys']['country']
    city_pd.loc[index, 'Date'] = response['dt']
city_pd.to_csv(output_data_file)
city_pd.head()
# Out:
#               city      Lat       Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0         cidreira -30.1811  -50.2056   294.69       66         67        9.6
# 1  bambous virieux -20.3428   57.7575   300.29       94         75       1.54
# 2         coos bay  43.3665 -124.2179   285.33       97        100        3.6
# 3    half moon bay  37.4636 -122.4286   297.53       64          0       8.23
# 4           torbay  47.6666  -52.7314   276.35       98        100      11.32
#
#   Country        Date
# 0      BR  1647903226
# 1      MU  1647903226
# 2      US  1647903227
# 3      US  1647903227
# 4      CA  1647903227

# %%
# Remove object columns
city_statistics = city_pd[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']]

# Change columns type to numbers for statistics calculations

city_statistics = city_statistics.astype({"Lat": 'float64', 
                                          "Lng": 'float64', 
                                          "Max Temp": 'float64', 
                                          "Humidity": 'float64', 
                                          "Cloudiness": 'float64', 
                                          "Wind Speed": 'float64',
                                          "Date": 'int64'})
city_statistics.describe(include='all')
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  587.000000  587.000000  587.000000  587.000000  587.000000  587.000000
# mean    18.684466   20.247144  286.407973   72.398637   58.618399    3.874412
# std     32.726649   88.869195   14.099900   21.711682   39.170985    2.948127
# min    -54.800000 -175.200000  244.940000    2.000000    0.000000    0.000000
# 25%     -8.912200  -58.915500  276.100000   61.000000   20.000000    1.855000
# 50%     22.285500   26.756600  291.070000   78.000000   72.000000    3.090000
# 75%     44.590900   97.461400  297.620000   89.000000   98.500000    4.995000
# max     78.218600  179.316700  310.300000  100.000000  100.000000   22.640000
#
#                Date
# count  5.870000e+02
# mean   1.647903e+09
# std    7.510775e+01
# min    1.647903e+09
# 25%    1.647903e+09
# 50%    1.647903e+09
# 75%    1.647903e+09
# max    1.647904e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Check for cities with humidity over 100%

city_pd = city_pd.astype({"Lat": 'float64', 
                          "Lng": 'float64', 
                          "Max Temp": 'float64', 
                          "Humidity": 'float64', 
                          "Cloudiness": 'float64', 
                          "Wind Speed": 'float64',
                          "Date": 'int64'})

city_data = city_pd.loc[(city_pd['Humidity']) <= 100 , :]
if (len(city_data) == len(city_pd)):
    print("No cities with humidity over 100% found")
else:
    city_high_humidity = city_pd.loc[(city_pd['Humidity']) > 100 , :]
    print(f"{len(city_pd)-len(city_data)} cities with humidity over 100% found")
    city_statistics.describe(include='all')
# Out:
# No cities with humidity over 100% found

# %%
#  Get the indices of cities that have humidity over 100%.
# city_high_humidity

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data
clean_city_data.head()
# Out:
#               city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         cidreira -30.1811  -50.2056    294.69      66.0        67.0
# 1  bambous virieux -20.3428   57.7575    300.29      94.0        75.0
# 2         coos bay  43.3665 -124.2179    285.33      97.0       100.0
# 3    half moon bay  37.4636 -122.4286    297.53      64.0         0.0
# 4           torbay  47.6666  -52.7314    276.35      98.0       100.0
#
#    Wind Speed Country        Date
# 0        9.60      BR  1647903226
# 1        1.54      MU  1647903226
# 2        3.60      US  1647903227
# 3        8.23      US  1647903227
# 4       11.32      CA  1647903227

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
max_temp_f = []
for i in clean_city_data['Max Temp']:
    max_temp_f.append(1.8*(i - 273)+32)
clean_city_data['Max Temp F'] = max_temp_f

# %%
clean_city_data
# Out:
#                 city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           cidreira -30.1811  -50.2056    294.69      66.0        67.0
# 1    bambous virieux -20.3428   57.7575    300.29      94.0        75.0
# 2           coos bay  43.3665 -124.2179    285.33      97.0       100.0
# 3      half moon bay  37.4636 -122.4286    297.53      64.0         0.0
# 4             torbay  47.6666  -52.7314    276.35      98.0       100.0
# ..               ...      ...       ...       ...       ...         ...
# 582            jilib   0.4883   42.7854    297.27      87.0         3.0
# 583            bafra  41.5678   35.9069    275.00      75.0        93.0
# 584         ngunguru -35.6167  174.5000    295.54      77.0        66.0
# 585         aripuana  -9.1667  -60.6333    295.89      97.0        85.0
# 586            arman  59.7000  150.1667    269.83      93.0       100.0
#
#      Wind Speed Country        Date  Max Temp F
# 0          9.60      BR  1647903226      71.042
# 1          1.54      MU  1647903226      81.122
# 2          3.60      US  1647903227      54.194
# 3          8.23      US  1647903227      76.154
# 4         11.32      CA  1647903227      38.030
# ..          ...     ...         ...         ...
# 582        2.70      SO  1647903430      75.686
# 583        3.71      TR  1647903374      35.600
# 584        5.89      NZ  1647903430      72.572
# 585        0.59      BR  1647903368      73.202
# 586        2.62      RU  1647903430      26.294
#
# [587 rows x 10 columns]

# %%
today = pd.to_datetime('today').strftime("%d/%m/%y")
invalid_characters = [",", "/", " "]

# %%
lat_sort = clean_city_data['Lat'].reset_index(drop=True)
x_limit = clean_city_data['Lat'].max()
x_limit_min = int(clean_city_data['Lat'].min())
y_values = np.round(clean_city_data['Max Temp F'], 2)
x_axis = clean_city_data['Lat']
plt_title = f"City Latitude vs. Max Temperature ({today})"
   
plt.figure(figsize=(10, 6))
plt.title(f"City Latitude vs. Max Temperature ({today})")
plt.xlabel("Latitide")
plt.ylabel("Max Temperature (F)")
plt.scatter(x_axis, y_values, marker="o", facecolors="tab:blue", edgecolors="black", alpha=0.75)
plt.grid(True)

# Removing invalid characters from title to allow title to used as filename
filename = plt_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_sort = clean_city_data['Lat'].reset_index(drop=True)
x_limit = clean_city_data['Lat'].max()
x_limit_min = int(clean_city_data['Lat'].min())
y_values = np.round(clean_city_data['Humidity'], 2)
x_axis = clean_city_data['Lat']
plt.figure(figsize=(10, 6))

plt_title = f"City Latitude vs. Humidity ({today})"
plt.title(plt_title)

plt.xlabel("Latitide")
plt.ylabel("Humidity (%)")
plt.scatter(x_axis, y_values, marker="o", facecolors="tab:blue", edgecolors="black", alpha=0.75)
plt.grid(True)

# Removing invalid characters from title to allow title to used as filename
filename = plt_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_sort = clean_city_data['Lat'].reset_index(drop=True)
x_limit = clean_city_data['Lat'].max()
x_limit_min = int(clean_city_data['Lat'].min())
y_values = np.round(clean_city_data['Cloudiness'], 2)
x_axis = clean_city_data['Lat']
plt.figure(figsize=(10, 6))

plt_title = f"City Latitude vs. Cloudiness ({today})"
plt.title(plt_title)

plt.xlabel("Latitide")
plt.ylabel("Cloudiness (%)")
plt.scatter(x_axis, y_values, marker="o", facecolors="tab:blue", edgecolors="black", alpha=0.75)

plt.grid(True)

# Removing invalid characters from title to allow title to used as filename
filename = plt_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_sort = clean_city_data['Lat'].reset_index(drop=True)
x_limit = clean_city_data['Lat'].max()
x_limit_min = int(clean_city_data['Lat'].min())
y_values = np.round(clean_city_data['Wind Speed'], 2)
x_axis = clean_city_data['Lat']
plt.figure(figsize=(10, 6))
plt_title = f"City Latitude vs. Wind Speed ({today})"
plt.title(plt_title)
plt.xlabel("Latitide")
plt.ylabel("Wind Speed (mph)")
plt.scatter(x_axis, y_values, marker="o", facecolors="tab:blue", edgecolors="black", alpha=0.75)

plt.grid(True)

# Removing invalid characters from title to allow title to used as filename
filename = plt_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
import scipy.stats as st
from scipy.stats import linregress
Nth_hemp = clean_city_data.loc[(clean_city_data['Lat']) > 0 , :]
Sth_hemp = clean_city_data.loc[(clean_city_data['Lat']) < 0 , :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_axis = Nth_hemp['Max Temp']
latitude = Nth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Max Temperature"
plot_title = "Northern Hemisphere - Max Temp vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
plt.annotate(line_eq,(45, 300),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")

# Removing invalid characters from title to allow title to used as filename
filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png")
plt.show()
# Out:
# The r-squared is: 0.772914825692737

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_axis = Sth_hemp['Max Temp']
latitude = Sth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Max Temperature"
plot_title = "Southern Hemisphere - Max Temp vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
plt.annotate(line_eq,(-20, 283),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png")
plt.show()
# Out:
# The r-squared is: 0.21389176202628027

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_axis = Nth_hemp['Humidity']
latitude = Nth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Humidity (%)"
plot_title = "Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
plt.annotate(line_eq,(52, 15),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png")
plt.show()
# Out:
# The r-squared is: 0.08391773525325216

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_axis = Sth_hemp['Humidity']
latitude = Sth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Humidity (%)"
plot_title = "Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
plt.annotate(line_eq,(-15, 35),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png")
plt.show()
# Out:
# The r-squared is: 0.16947160764164867

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_axis = Nth_hemp['Cloudiness']
latitude = Nth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Cloudiness (%)"
plot_title = "Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
plt.annotate(line_eq,(76.5, 47),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png")
plt.show()
# Out:
# The r-squared is: 0.021305180215708753

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_axis = Sth_hemp['Cloudiness']
latitude = Sth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Cloudiness (%)"
plot_title = "Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
plt.annotate(line_eq,(-7, 44),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png")
plt.show()
# Out:
# The r-squared is: 0.05664776564412767

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_axis = Nth_hemp['Wind Speed']
latitude = Nth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Wind Speed (mph)"
plot_title = f"Northern Hemisphere - {y_label} vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
plt.annotate(line_eq,(25, 17),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png")
plt.show()
# Out:
# The r-squared is: 0.007329576865578029

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_axis = Sth_hemp['Wind Speed']
latitude = Sth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Wind Speed (mph)"
plot_title = f"Southern Hemisphere - {y_label} vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
plt.annotate(line_eq,(-20, 12.5),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png")
plt.show()
# Out:
# The r-squared is: 0.1470282363106242
