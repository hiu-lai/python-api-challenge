# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"
cities_csv = pd.read_csv(output_data_file)

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
#     print(city)
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

print("Beginning Data Retrieval")
print("-------------------------")
i = 0
valid_cities = []
for city in cities:
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    try:
        response = requests.get(query_url).json()
        testcon = response['clouds']['all']
        i = i + 1
        iset = int(i/50) + 1
        cityid = i - ((iset - 1) * 50)
        print(f"Processing Record {cityid} of Set {iset} | {city}")
        valid_cities.append(city)
    except (KeyError, IndexError):
        print("City not found. Skipping...")
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | pyinmana
# Processing Record 2 of Set 1 | mwense
# City not found. Skipping...
# Processing Record 3 of Set 1 | cristinapolis
# Processing Record 4 of Set 1 | rawson
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | abu kamal
# City not found. Skipping...
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | fort morgan
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | mayor pablo lagerenza
# Processing Record 11 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 12 of Set 1 | paamiut
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | constitucion
# Processing Record 15 of Set 1 | lubango
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | ponca city
# Processing Record 19 of Set 1 | touros
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | nikolskoye
# Processing Record 23 of Set 1 | leua
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | brest
# Processing Record 26 of Set 1 | khatanga
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | kabare
# Processing Record 30 of Set 1 | konya
# Processing Record 31 of Set 1 | aldan
# City not found. Skipping...
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | brae
# Processing Record 34 of Set 1 | chambas
# Processing Record 35 of Set 1 | cabo san lucas
# City not found. Skipping...
# Processing Record 36 of Set 1 | srivardhan
# Processing Record 37 of Set 1 | tiznit
# Processing Record 38 of Set 1 | westport
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | nanortalik
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | turukhansk
# Processing Record 43 of Set 1 | vanavara
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | bengkulu
# Processing Record 48 of Set 1 | xinpu
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 0 of Set 2 | victoria
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | saskylakh
# City not found. Skipping...
# Processing Record 4 of Set 2 | laguna
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 4 | sotnikovskoye
# Processing Record 37 of Set 4 | williams lake
# Processing Record 38 of Set 4 | price
# City not found. Skipping...
# Processing Record 39 of Set 4 | noumea
# Processing Record 40 of Set 4 | esperance
# Processing Record 41 of Set 4 | kaitangata
# Processing Record 42 of Set 4 | ahipara
# Processing Record 43 of Set 4 | zyryanka
# Processing Record 44 of Set 4 | codrington
# Processing Record 45 of Set 4 | lata
# Processing Record 46 of Set 4 | senno
# City not found. Skipping...
# Processing Record 47 of Set 4 | bafra
# Processing Record 48 of Set 4 | pacific grove
# Processing Record 49 of Set 4 | comodoro rivadavia
# Processing Record 0 of Set 5 | iskateley
# Processing Record 1 of Set 5 | boende
# Processing Record 2 of Set 5 | faya
# Processing Record 3 of Set 5 | hammerfest
# Processing Record 4 of Set 5 | riyadh
# Processing Record 5 of Set 5 | milkovo
# City not found. Skipping...
# Processing Record 6 of Set 5 | hilo
# Processing Record 7 of Set 5 | bushehr
# Processing Record 8 of Set 5 | rio grande
# Processing Record 9 of Set 5 | hellin
# Processing Record 10 of Set 5 | demirci
# Processing Record 11 of Set 5 | tarascon
# Processing Record 12 of Set 5 | chunhuhub
# City not found. Skipping...
# Processing Record 13 of Set 5 | ndola
# Processing Record 14 of Set 5 | tuktoyaktuk
# Processing Record 15 of Set 5 | goderich
# Processing Record 16 of Set 5 | prince rupert
# Processing Record 17 of Set 5 | bethel
# Processing Record 18 of Set 5 | oistins
# City not found. Skipping...
# Processing Record 19 of Set 5 | mahebourg
# Processing Record 20 of Set 5 | wanning
# Processing Record 21 of Set 5 | sorland
# Processing Record 22 of Set 5 | georgetown
# Processing Record 23 of Set 5 | cherskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 5 | scottsbluff
# Processing Record 25 of Set 5 | aracruz
# Processing Record 26 of Set 5 | watertown
# City not found. Skipping...
# Processing Record 27 of Set 5 | tankhoy
# Processing Record 28 of Set 5 | acapulco
# Processing Record 29 of Set 5 | xining
# Processing Record 30 of Set 5 | ilhabela
# Processing Record 31 of Set 5 | grand gaube
# Processing Record 32 of Set 5 | skjervoy
# Processing Record 33 of Set 5 | sioux lookout
# Processing Record 34 of Set 5 | pabna
# Processing Record 35 of Set 5 | kiruna
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 5 | labuhan
# Processing Record 37 of Set 5 | tabuk
# Processing Record 38 of Set 5 | mount isa
# Processing Record 39 of Set 5 | shaunavon
# Processing Record 40 of Set 5 | sabang
# Processing Record 41 of Set 5 | luderitz
# Processing Record 42 of Set 5 | chepo
# Processing Record 43 of Set 5 | san pedro
# Processing Record 44 of Set 5 | sitka
# Processing Record 45 of Set 5 | george
# Processing Record 46 of Set 5 | nome
# Processing Record 47 of Set 5 | calamar
# Processing Record 48 of Set 5 | aripuana
# Processing Record 49 of Set 5 | orocue
# Processing Record 0 of Set 6 | saint george
# Processing Record 1 of Set 6 | lorengau
# Processing Record 2 of Set 6 | farafangana
# Processing Record 3 of Set 6 | kudahuvadhoo
# Processing Record 4 of Set 6 | belyy yar
# Processing Record 5 of Set 6 | coolum beach
# City not found. Skipping...
# Processing Record 6 of Set 6 | namtsy
# Processing Record 7 of Set 6 | mitsamiouli
# City not found. Skipping...
# Processing Record 8 of Set 6 | kenai
# Processing Record 9 of Set 6 | kande
# Processing Record 10 of Set 6 | naze
# Processing Record 11 of Set 6 | son la
# Processing Record 12 of Set 6 | saint-augustin
# Processing Record 13 of Set 6 | bubaque
# Processing Record 14 of Set 6 | yubari
# Processing Record 15 of Set 6 | igarka
# Processing Record 16 of Set 6 | mayo
# Processing Record 17 of Set 6 | kutum
# Processing Record 18 of Set 6 | faanui
# Processing Record 19 of Set 6 | rudnogorsk
# Processing Record 20 of Set 6 | kitimat
# City not found. Skipping...
# Processing Record 21 of Set 6 | la paz
# Processing Record 22 of Set 6 | ardesen
# Processing Record 23 of Set 6 | elban
# Processing Record 24 of Set 6 | yumen
# Processing Record 25 of Set 6 | isangel
# Processing Record 26 of Set 6 | mbaiki
# Processing Record 27 of Set 6 | ghanzi
# Processing Record 28 of Set 6 | ixtapa
# Processing Record 29 of Set 6 | torbay
# City not found. Skipping...
# Processing Record 30 of Set 6 | christchurch
# Processing Record 31 of Set 6 | plettenberg bay
# Processing Record 32 of Set 6 | pierre
# Processing Record 33 of Set 6 | sohag
# Processing Record 34 of Set 6 | srednekolymsk
# Processing Record 35 of Set 6 | ormara
# Processing Record 36 of Set 6 | takoradi
# Processing Record 37 of Set 6 | bocanda
# Processing Record 38 of Set 6 | murzzuschlag
# Processing Record 39 of Set 6 | borogontsy
# Processing Record 40 of Set 6 | bahia blanca
# Processing Record 41 of Set 6 | lingao
# Processing Record 42 of Set 6 | hamilton
# Processing Record 43 of Set 6 | namatanai
# Processing Record 44 of Set 6 | general bravo
# Processing Record 45 of Set 6 | richards bay
# Processing Record 46 of Set 6 | bandarbeyla
# Processing Record 47 of Set 6 | abu dhabi
# City not found. Skipping...
# Processing Record 48 of Set 6 | baherden
# Processing Record 49 of Set 6 | bhimavaram
# Processing Record 0 of Set 7 | aktau
# City not found. Skipping...
# Processing Record 1 of Set 7 | panaba
# Processing Record 2 of Set 7 | kalabo
# Processing Record 3 of Set 7 | maniitsoq
# Processing Record 4 of Set 7 | nikel
# Processing Record 5 of Set 7 | lahaina
# Processing Record 6 of Set 7 | leh
# Processing Record 7 of Set 7 | murgab
# Processing Record 8 of Set 7 | alekseyevsk
# Processing Record 9 of Set 7 | camacha
# Processing Record 10 of Set 7 | iraquara
# Processing Record 11 of Set 7 | necochea
# Processing Record 12 of Set 7 | bowen
# Processing Record 13 of Set 7 | keratea
# Processing Record 14 of Set 7 | portland
# City not found. Skipping...
# Processing Record 15 of Set 7 | okha
# Processing Record 16 of Set 7 | kruisfontein
# City not found. Skipping...
# Processing Record 17 of Set 7 | guerrero negro
# Processing Record 18 of Set 7 | narsaq
# Processing Record 19 of Set 7 | aklavik
# City not found. Skipping...
# Processing Record 20 of Set 7 | okahandja
# Processing Record 21 of Set 7 | hasaki
# Processing Record 22 of Set 7 | los llanos de aridane
# City not found. Skipping...
# Processing Record 23 of Set 7 | lebu
# Processing Record 24 of Set 7 | orlik
# Processing Record 45 of Set 8 | saint-georges
# Processing Record 46 of Set 8 | makokou
# Processing Record 47 of Set 8 | dalbandin
# Processing Record 48 of Set 8 | tevaitoa
# Processing Record 49 of Set 8 | pedra branca
# Processing Record 0 of Set 9 | krasnoselkup
# Processing Record 1 of Set 9 | ziezmariai
# Processing Record 2 of Set 9 | conde
# City not found. Skipping...
# Processing Record 3 of Set 9 | mbini
# Processing Record 4 of Set 9 | marzuq
# Processing Record 5 of Set 9 | manaus
# Processing Record 6 of Set 9 | kazachinskoye
# Processing Record 7 of Set 9 | axim
# Processing Record 8 of Set 9 | caravelas
# Processing Record 9 of Set 9 | savannah bight
# Processing Record 10 of Set 9 | tongren
# Processing Record 11 of Set 9 | vestmannaeyjar
# Processing Record 12 of Set 9 | mao
# Processing Record 13 of Set 9 | chuy
# Processing Record 14 of Set 9 | patan
# Processing Record 15 of Set 9 | beberibe
# Processing Record 16 of Set 9 | praia
# Processing Record 17 of Set 9 | platteville
# Processing Record 18 of Set 9 | mexico
# Processing Record 19 of Set 9 | mount gambier
# Processing Record 20 of Set 9 | kabanjahe
# Processing Record 21 of Set 9 | volovo
# Processing Record 22 of Set 9 | kibaya
# Processing Record 23 of Set 9 | issoudun
# Processing Record 24 of Set 9 | gat
# Processing Record 25 of Set 9 | altamira
# Processing Record 26 of Set 9 | nabire
# Processing Record 27 of Set 9 | candelaria
# Processing Record 28 of Set 9 | alyangula
# Processing Record 29 of Set 9 | imbituba
# Processing Record 30 of Set 9 | krasnoborsk
# Processing Record 31 of Set 9 | tutoia
# Processing Record 32 of Set 9 | maceio
# Processing Record 33 of Set 9 | la ronge
# Processing Record 34 of Set 9 | gimli
# Processing Record 35 of Set 9 | mayskiy
# Processing Record 36 of Set 9 | raudeberg
# Processing Record 37 of Set 9 | whitehorse
# Processing Record 38 of Set 9 | port macquarie
# Processing Record 39 of Set 9 | antalaha
# Processing Record 40 of Set 9 | ocampo
# Processing Record 41 of Set 9 | gloversville
# Processing Record 42 of Set 9 | lethem
# Processing Record 43 of Set 9 | pangnirtung
# Processing Record 44 of Set 9 | santa marta
# Processing Record 45 of Set 9 | praia da vitoria
# Processing Record 46 of Set 9 | ascension
# Processing Record 47 of Set 9 | catalao
# Processing Record 48 of Set 9 | vardo
# Processing Record 49 of Set 9 | lobito
# Processing Record 0 of Set 10 | samarai
# Processing Record 1 of Set 10 | cap-aux-meules
# City not found. Skipping...
# Processing Record 2 of Set 10 | san cristobal
# Processing Record 3 of Set 10 | glasgow
# Processing Record 4 of Set 10 | vostok
# Processing Record 5 of Set 10 | salamiyah
# Processing Record 6 of Set 10 | phon
# Processing Record 7 of Set 10 | kalmunai
# Processing Record 8 of Set 10 | puerto ayacucho
# Processing Record 9 of Set 10 | areosa
# Processing Record 10 of Set 10 | ekhabi
# Processing Record 11 of Set 10 | tateyama
# Processing Record 12 of Set 10 | gornopravdinsk
# Processing Record 13 of Set 10 | hovd
# Processing Record 14 of Set 10 | omsukchan
# Processing Record 15 of Set 10 | batagay-alyta
# Processing Record 16 of Set 10 | korla
# Processing Record 17 of Set 10 | taggia
# City not found. Skipping...
# Processing Record 18 of Set 10 | ramotswa
# Processing Record 19 of Set 10 | saint-agapit
# Processing Record 20 of Set 10 | rodeo
# Processing Record 21 of Set 10 | vangaindrano
# Processing Record 22 of Set 10 | whyalla
# Processing Record 23 of Set 10 | namibe
# Processing Record 24 of Set 10 | oyama
# Processing Record 25 of Set 10 | kloulklubed
# Processing Record 26 of Set 10 | dale
# Processing Record 27 of Set 10 | haines junction
# Processing Record 28 of Set 10 | krasnaya gora
# Processing Record 29 of Set 10 | trabzon
# Processing Record 30 of Set 10 | parsons
# Processing Record 31 of Set 10 | independencia
# Processing Record 32 of Set 10 | nishihara
# Processing Record 33 of Set 10 | bilibino
# Processing Record 34 of Set 10 | kilindoni
# Processing Record 35 of Set 10 | filadelfia
# Processing Record 36 of Set 10 | kodinsk
# Processing Record 37 of Set 10 | chapleau
# City not found. Skipping...
# Processing Record 38 of Set 10 | la rioja
# Processing Record 39 of Set 10 | cairns
# Processing Record 40 of Set 10 | sangamner
# Processing Record 41 of Set 10 | soure
# Processing Record 42 of Set 10 | jaltenango
# Processing Record 43 of Set 10 | yulara
# Processing Record 44 of Set 10 | macusani
# Processing Record 45 of Set 10 | the valley
# Processing Record 46 of Set 10 | ulladulla
# Processing Record 47 of Set 10 | qostanay
# Processing Record 48 of Set 10 | evensk
# Processing Record 49 of Set 10 | rafaela
# City not found. Skipping...
# Processing Record 0 of Set 11 | wenatchee
# Processing Record 1 of Set 11 | olavarria
# Processing Record 2 of Set 11 | sovetskoye
# Processing Record 3 of Set 11 | itoman
# Processing Record 4 of Set 11 | ilulissat
# Processing Record 5 of Set 11 | lensk
# Processing Record 6 of Set 11 | novyy svit
# Processing Record 7 of Set 11 | iquitos
# Processing Record 8 of Set 11 | saint-pierre
# Processing Record 9 of Set 11 | nynashamn
# Processing Record 10 of Set 11 | doha
# Processing Record 11 of Set 11 | svolvaer
# Processing Record 12 of Set 11 | weligama
# Processing Record 13 of Set 11 | jacobina
# Processing Record 14 of Set 11 | odda
# Processing Record 15 of Set 11 | boa vista
# Processing Record 16 of Set 11 | pratapgarh
# Processing Record 17 of Set 11 | beringovskiy
# Processing Record 18 of Set 11 | belmonte
# Processing Record 19 of Set 11 | damietta
# Processing Record 20 of Set 11 | galle
# Processing Record 21 of Set 11 | lavrentiya
# City not found. Skipping...
# Processing Record 22 of Set 11 | boyolangu
# Processing Record 23 of Set 11 | bloomington
# City not found. Skipping...
# Processing Record 24 of Set 11 | yangshan
# Processing Record 25 of Set 11 | kattivakkam
# Processing Record 26 of Set 11 | lukulu
# Processing Record 27 of Set 11 | tigzirt
# Processing Record 28 of Set 11 | bulgan
# Processing Record 29 of Set 11 | ouadda
# Processing Record 30 of Set 11 | lerwick
# Processing Record 31 of Set 11 | talara
# Processing Record 32 of Set 11 | pizarro
# Processing Record 33 of Set 11 | miragoane
# Processing Record 34 of Set 11 | am timan
# Processing Record 35 of Set 11 | ulaanbaatar
# Processing Record 36 of Set 11 | wajima
# Processing Record 37 of Set 11 | vierzon
# Processing Record 38 of Set 11 | menongue
# Processing Record 39 of Set 11 | lubumbashi
# Processing Record 40 of Set 11 | gamba
# Processing Record 41 of Set 11 | mercedes
# Processing Record 42 of Set 11 | superior
# Processing Record 43 of Set 11 | dauriya
# Processing Record 44 of Set 11 | sao jose da coroa grande
# Processing Record 45 of Set 11 | rudbar
# Processing Record 46 of Set 11 | libertador general san martin
# Processing Record 47 of Set 11 | bonavista
# City not found. Skipping...
# Processing Record 48 of Set 11 | zaysan
# Processing Record 49 of Set 11 | santa cruz
# Processing Record 0 of Set 12 | atar
# Processing Record 1 of Set 12 | abnub
# Processing Record 2 of Set 12 | nuuk
# Processing Record 3 of Set 12 | antsohihy
# Processing Record 4 of Set 12 | rio cuarto
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Loading valid cities into dataframe
city_pd = pd.DataFrame({'city': valid_cities})

city_pd['Lat'] = ""
city_pd['Lng'] = ""
city_pd['Max Temp'] = ""
city_pd['Humidity'] = ""
city_pd['Cloudiness'] = ""
city_pd['Wind Speed'] = ""
city_pd['Country'] = ""
city_pd['Date'] = ""

# ============ TEST DATA =========
# city = "okha"
# query_url = url + "appid=" + weather_api_key + "&q=" + city
# requests.get(query_url).json()
# ================================

for index, row in city_pd.iterrows():
    city = row['city']
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    city_pd.loc[index, 'Lat'] = response['coord']['lat']
    city_pd.loc[index, 'Lng'] = response['coord']['lon']
    city_pd.loc[index, 'Max Temp'] = response['main']['temp_max']
    city_pd.loc[index, 'Humidity'] = response['main']['humidity']
    city_pd.loc[index, 'Cloudiness'] = response['clouds']['all']
    city_pd.loc[index, 'Wind Speed'] = response['wind']['speed']
    city_pd.loc[index, 'Country'] = response['sys']['country']
    city_pd.loc[index, 'Date'] = response['dt']
city_pd.to_csv(output_data_file)
city_pd.head()
# Out:
#             city      Lat      Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0       pyinmana  19.7333  96.2167   300.83       67         98       1.48
# 1         mwense -10.3845   28.698   292.25       96         86        2.2
# 2  cristinapolis -11.4756 -37.7553   295.33       91          8        1.3
# 3         rawson -43.3002 -65.1023   290.97       44         97       6.78
# 4     bredasdorp -34.5322  20.0403   293.45       88         73       4.76
#
#   Country        Date
# 0      MM  1647925782
# 1      ZM  1647925783
# 2      BR  1647925783
# 3      AR  1647925784
# 4      ZA  1647925784

# %%
# Remove object columns
city_statistics = city_pd[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']]

# Change columns type to numbers for statistics calculations

city_statistics = city_statistics.astype({"Lat": 'float64', 
                                          "Lng": 'float64', 
                                          "Max Temp": 'float64', 
                                          "Humidity": 'float64', 
                                          "Cloudiness": 'float64', 
                                          "Wind Speed": 'float64',
                                          "Date": 'int64'})
city_statistics.describe(include='all')
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  554.000000  554.000000  554.000000  554.000000  554.000000  554.000000
# mean    20.697864   13.403888  285.657220   73.555957   59.341155    3.879278
# std     33.841613   89.083109   13.962054   20.785774   39.888963    2.737010
# min    -54.800000 -175.200000  243.120000    1.000000    0.000000    0.000000
# 25%     -8.230975  -62.815625  274.747500   65.000000   15.250000    1.822500
# 50%     26.169450   18.920800  288.370000   78.000000   74.000000    3.150000
# 75%     48.801100   86.474200  297.502500   89.000000   99.000000    5.317500
# max     78.218600  179.316700  312.180000  100.000000  100.000000   15.180000
#
#                Date
# count  5.540000e+02
# mean   1.647926e+09
# std    6.275450e+01
# min    1.647926e+09
# 25%    1.647926e+09
# 50%    1.647926e+09
# 75%    1.647926e+09
# max    1.647926e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Check for cities with humidity over 100%

city_pd = city_pd.astype({"Lat": 'float64', 
                          "Lng": 'float64', 
                          "Max Temp": 'float64', 
                          "Humidity": 'float64', 
                          "Cloudiness": 'float64', 
                          "Wind Speed": 'float64',
                          "Date": 'int64'})

city_data = city_pd.loc[(city_pd['Humidity']) <= 100 , :]
if (len(city_data) == len(city_pd)):
    print("No cities with humidity over 100% found")
else:
    city_high_humidity = city_pd.loc[(city_pd['Humidity']) > 100 , :]
    print(f"{len(city_pd)-len(city_data)} cities with humidity over 100% found")
    city_statistics.describe(include='all')
# Out:
# No cities with humidity over 100% found

# %%
#  Get the indices of cities that have humidity over 100%.
# city_high_humidity

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data
clean_city_data.head()
# Out:
#             city      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0       pyinmana  19.7333  96.2167    300.83      67.0        98.0
# 1         mwense -10.3845  28.6980    292.25      96.0        86.0
# 2  cristinapolis -11.4756 -37.7553    295.33      91.0         8.0
# 3         rawson -43.3002 -65.1023    290.97      44.0        97.0
# 4     bredasdorp -34.5322  20.0403    293.45      88.0        73.0
#
#    Wind Speed Country        Date
# 0        1.48      MM  1647925782
# 1        2.20      ZM  1647925783
# 2        1.30      BR  1647925783
# 3        6.78      AR  1647925784
# 4        4.76      ZA  1647925784

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
max_temp_f = []
for i in clean_city_data['Max Temp']:
    max_temp_f.append(1.8*(i - 273)+32)
clean_city_data['Max Temp F'] = max_temp_f

# %%
clean_city_data
# Out:
#               city      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0         pyinmana  19.7333  96.2167    300.83      67.0        98.0
# 1           mwense -10.3845  28.6980    292.25      96.0        86.0
# 2    cristinapolis -11.4756 -37.7553    295.33      91.0         8.0
# 3           rawson -43.3002 -65.1023    290.97      44.0        97.0
# 4       bredasdorp -34.5322  20.0403    293.45      88.0        73.0
# ..             ...      ...      ...       ...       ...         ...
# 549           atar  20.5169 -13.0499    293.43      26.0         0.0
# 550          abnub  27.2696  31.1511    283.60      57.0         0.0
# 551           nuuk  64.1835 -51.7216    262.49      85.0        20.0
# 552      antsohihy -14.8796  47.9875    298.23      84.0         7.0
# 553     rio cuarto -33.1307 -64.3499    290.19      70.0         4.0
#
#      Wind Speed Country        Date  Max Temp F
# 0          1.48      MM  1647925782      82.094
# 1          2.20      ZM  1647925783      66.650
# 2          1.30      BR  1647925783      72.194
# 3          6.78      AR  1647925784      64.346
# 4          4.76      ZA  1647925784      68.810
# ..          ...     ...         ...         ...
# 549        4.54      MR  1647925941      68.774
# 550        5.59      EG  1647925941      51.080
# 551        5.14      GL  1647925941      13.082
# 552        1.67      MG  1647925941      77.414
# 553        3.76      AR  1647925941      62.942
#
# [554 rows x 10 columns]

# %%
today = pd.to_datetime('today').strftime("%d/%m/%y")
invalid_characters = [",", "/", " "]

# %%
lat_sort = clean_city_data['Lat'].reset_index(drop=True)
x_limit = clean_city_data['Lat'].max()
x_limit_min = int(clean_city_data['Lat'].min())
y_values = np.round(clean_city_data['Max Temp F'], 2)
x_axis = clean_city_data['Lat']
plt_title = f"City Latitude vs. Max Temperature ({today})"
   
plt.figure(figsize=(10, 6))
plt.title(f"City Latitude vs. Max Temperature ({today})")
plt.xlabel("Latitide")
plt.ylabel("Max Temperature (F)")

plt.scatter(x_axis, y_values, marker="o", facecolors="tab:blue", edgecolors="black", alpha=0.75)
plt.grid(True)


# Removing invalid characters from title to allow title to used as filename
filename = plt_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_sort = clean_city_data['Lat'].reset_index(drop=True)
x_limit = clean_city_data['Lat'].max()
x_limit_min = int(clean_city_data['Lat'].min())
y_values = np.round(clean_city_data['Humidity'], 2)
x_axis = clean_city_data['Lat']
plt.figure(figsize=(10, 6))

plt_title = f"City Latitude vs. Humidity ({today})"
plt.title(plt_title)

plt.xlabel("Latitide")
plt.ylabel("Humidity (%)")
plt.scatter(x_axis, y_values, marker="o", facecolors="tab:blue", edgecolors="black", alpha=0.75)
plt.grid(True)

# Removing invalid characters from title to allow title to used as filename
filename = plt_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_sort = clean_city_data['Lat'].reset_index(drop=True)
x_limit = clean_city_data['Lat'].max()
x_limit_min = int(clean_city_data['Lat'].min())
y_values = np.round(clean_city_data['Cloudiness'], 2)
x_axis = clean_city_data['Lat']
plt.figure(figsize=(10, 6))

plt_title = f"City Latitude vs. Cloudiness ({today})"
plt.title(plt_title)

plt.xlabel("Latitide")
plt.ylabel("Cloudiness (%)")
plt.scatter(x_axis, y_values, marker="o", facecolors="tab:blue", edgecolors="black", alpha=0.75)

plt.grid(True)

# Removing invalid characters from title to allow title to used as filename
filename = plt_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_sort = clean_city_data['Lat'].reset_index(drop=True)
x_limit = clean_city_data['Lat'].max()
x_limit_min = int(clean_city_data['Lat'].min())
y_values = np.round(clean_city_data['Wind Speed'], 2)
x_axis = clean_city_data['Lat']
plt.figure(figsize=(10, 6))
plt_title = f"City Latitude vs. Wind Speed ({today})"
plt.title(plt_title)
plt.xlabel("Latitide")
plt.ylabel("Wind Speed (mph)")
plt.scatter(x_axis, y_values, marker="o", facecolors="tab:blue", edgecolors="black", alpha=0.75)

plt.grid(True)

# Removing invalid characters from title to allow title to used as filename
filename = plt_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
import scipy.stats as st
from scipy.stats import linregress
Nth_hemp = clean_city_data.loc[(clean_city_data['Lat']) > 0 , :]
Sth_hemp = clean_city_data.loc[(clean_city_data['Lat']) < 0 , :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_axis = Nth_hemp['Max Temp']
latitude = Nth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Max Temperature"
plot_title = "Northern Hemisphere - Max Temp vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(45, 300),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

# Removing invalid characters from title to allow title to used as filename
filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.7938369953702433
# Line Equation: y = -0.64x + 307.12

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_axis = Sth_hemp['Max Temp']
latitude = Sth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Max Temperature"
plot_title = "Southern Hemisphere - Max Temp vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(-20, 283),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.16522163429582257
# Line Equation: y = 0.18x + 299.05

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_axis = Nth_hemp['Humidity']
latitude = Nth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Humidity (%)"
plot_title = "Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(52, 15),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.08679593381530723
# Line Equation: y = 0.33x + 58.14

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_axis = Sth_hemp['Humidity']
latitude = Sth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Humidity (%)"
plot_title = "Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(-15, 35),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.09504054790491158
# Line Equation: y = 0.39x + 86.71

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_axis = Nth_hemp['Cloudiness']
latitude = Nth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Cloudiness (%)"
plot_title = "Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(76.5, 47),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.02090987286955004
# Line Equation: y = 0.3x + 44.98

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_axis = Sth_hemp['Cloudiness']
latitude = Sth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Cloudiness (%)"
plot_title = "Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(-7, 44),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.05722061520908704
# Line Equation: y = 0.64x + 77.56

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_axis = Nth_hemp['Wind Speed']
latitude = Nth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Wind Speed (mph)"
plot_title = f"Northern Hemisphere - {y_label} vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(25, 17),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.021557922585799062
# Line Equation: y = 0.02x + 3.23

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_axis = Sth_hemp['Wind Speed']
latitude = Sth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Wind Speed (mph)"
plot_title = f"Southern Hemisphere - {y_label} vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")
filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.1176832428805279
# Line Equation: y = -0.06x + 2.21
