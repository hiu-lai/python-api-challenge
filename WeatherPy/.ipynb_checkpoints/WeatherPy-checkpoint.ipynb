# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"
cities_csv = pd.read_csv(output_data_file)

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
#     print(city)
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

print("Beginning Data Retrieval")
print("-------------------------")
i = 0
valid_cities = []
for city in cities:
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    try:
        response = requests.get(query_url).json()
        testcon = response['clouds']['all']
        i = i + 1
        iset = int(i/50) + 1
        cityid = i - ((iset - 1) * 50)
        print(f"Processing Record {cityid} of Set {iset} | {city}")
        valid_cities.append(city)
    except (KeyError, IndexError):
        print("City not found. Skipping...")
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | gazojak
# Processing Record 2 of Set 1 | belvidere
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | wuwei
# Processing Record 5 of Set 1 | lompoc
# Processing Record 6 of Set 1 | whitehorse
# Processing Record 7 of Set 1 | malaya vishera
# Processing Record 8 of Set 1 | asau
# Processing Record 9 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 10 of Set 1 | nara
# City not found. Skipping...
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | mangrol
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | richards bay
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | nadym
# Processing Record 20 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | tautira
# City not found. Skipping...
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | beloha
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | araxa
# Processing Record 30 of Set 1 | catuday
# Processing Record 31 of Set 1 | victoria
# Processing Record 32 of Set 1 | champerico
# Processing Record 33 of Set 1 | chuy
# Processing Record 34 of Set 1 | poronaysk
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | tezu
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | gat
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | polikhronon
# Processing Record 44 of Set 1 | andros town
# Processing Record 45 of Set 1 | kargil
# Processing Record 46 of Set 1 | flinders
# Processing Record 47 of Set 1 | goderich
# Processing Record 48 of Set 1 | teknaf
# Processing Record 49 of Set 1 | sampit
# Processing Record 0 of Set 2 | polyarnyy
# Processing Record 1 of Set 2 | kilindoni
# Processing Record 2 of Set 2 | harper
# City not found. Skipping...
# Processing Record 3 of Set 2 | fort nelson
# Processing Record 4 of Set 2 | leh
# Processing Record 5 of Set 2 | moncao
# Processing Record 6 of Set 2 | aitape
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set 4 | castro
# Processing Record 49 of Set 4 | sucre
# Processing Record 0 of Set 5 | sycow
# Processing Record 1 of Set 5 | bafq
# Processing Record 2 of Set 5 | kemijarvi
# City not found. Skipping...
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | grand gaube
# Processing Record 5 of Set 5 | aksarka
# Processing Record 6 of Set 5 | boyolangu
# City not found. Skipping...
# Processing Record 7 of Set 5 | awbari
# Processing Record 8 of Set 5 | bomi
# Processing Record 9 of Set 5 | norman wells
# Processing Record 10 of Set 5 | labuhan
# Processing Record 11 of Set 5 | esperance
# Processing Record 12 of Set 5 | haines junction
# Processing Record 13 of Set 5 | laguna
# Processing Record 14 of Set 5 | villeta
# Processing Record 15 of Set 5 | tual
# Processing Record 16 of Set 5 | tuatapere
# Processing Record 17 of Set 5 | alenquer
# Processing Record 18 of Set 5 | fairbanks
# Processing Record 19 of Set 5 | vila franca do campo
# Processing Record 20 of Set 5 | pundaguitan
# Processing Record 21 of Set 5 | atuona
# Processing Record 22 of Set 5 | lorengau
# Processing Record 23 of Set 5 | caravelas
# Processing Record 24 of Set 5 | camocim
# Processing Record 25 of Set 5 | puno
# Processing Record 26 of Set 5 | coffs harbour
# Processing Record 27 of Set 5 | san andres
# Processing Record 28 of Set 5 | puerto ayora
# Processing Record 29 of Set 5 | kloulklubed
# Processing Record 30 of Set 5 | muleba
# Processing Record 31 of Set 5 | belmonte
# Processing Record 32 of Set 5 | kieta
# Processing Record 33 of Set 5 | sarangani
# Processing Record 34 of Set 5 | bom jesus da lapa
# Processing Record 35 of Set 5 | hailar
# Processing Record 36 of Set 5 | kindu
# City not found. Skipping...
# Processing Record 37 of Set 5 | roald
# Processing Record 38 of Set 5 | pangnirtung
# City not found. Skipping...
# Processing Record 39 of Set 5 | franklin
# Processing Record 40 of Set 5 | severo-kurilsk
# Processing Record 41 of Set 5 | namatanai
# Processing Record 42 of Set 5 | gawler
# Processing Record 43 of Set 5 | hobart
# Processing Record 44 of Set 5 | chingirlau
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 5 | prijepolje
# Processing Record 46 of Set 5 | ferkessedougou
# City not found. Skipping...
# Processing Record 47 of Set 5 | ilorin
# Processing Record 48 of Set 5 | liverpool
# Processing Record 49 of Set 5 | parit raja
# Processing Record 0 of Set 6 | griffith
# Processing Record 1 of Set 6 | hofn
# Processing Record 2 of Set 6 | araouane
# Processing Record 3 of Set 6 | boa viagem
# Processing Record 4 of Set 6 | marawi
# Processing Record 5 of Set 6 | uvat
# Processing Record 6 of Set 6 | dabakala
# Processing Record 7 of Set 6 | rogovatoye
# Processing Record 8 of Set 6 | masterton
# Processing Record 9 of Set 6 | ponta do sol
# Processing Record 10 of Set 6 | cam ranh
# Processing Record 11 of Set 6 | berlevag
# Processing Record 15 of Set 10 | klaksvik
# Processing Record 16 of Set 10 | chimore
# Processing Record 17 of Set 10 | kintampo
# Processing Record 18 of Set 10 | cuamba
# Processing Record 19 of Set 10 | amasya
# Processing Record 20 of Set 10 | sidi ali
# City not found. Skipping...
# Processing Record 21 of Set 10 | broome
# Processing Record 22 of Set 10 | vardo
# Processing Record 23 of Set 10 | gamba
# Processing Record 24 of Set 10 | qaqortoq
# Processing Record 25 of Set 10 | oga
# Processing Record 26 of Set 10 | hualmay
# Processing Record 27 of Set 10 | gornopravdinsk
# Processing Record 28 of Set 10 | mayumba
# Processing Record 29 of Set 10 | bathsheba
# Processing Record 30 of Set 10 | price
# Processing Record 31 of Set 10 | songjianghe
# Processing Record 32 of Set 10 | les cayes
# Processing Record 33 of Set 10 | skibbereen
# Processing Record 34 of Set 10 | nantucket
# Processing Record 35 of Set 10 | dali
# Processing Record 36 of Set 10 | mount gambier
# Processing Record 37 of Set 10 | kaitangata
# Processing Record 38 of Set 10 | bandarbeyla
# Processing Record 39 of Set 10 | kalianget
# Processing Record 40 of Set 10 | port augusta
# Processing Record 41 of Set 10 | bambanglipuro
# Processing Record 42 of Set 10 | mocuba
# Processing Record 43 of Set 10 | kiunga
# Processing Record 44 of Set 10 | fonte boa
# City not found. Skipping...
# Processing Record 45 of Set 10 | bengkulu
# City not found. Skipping...
# Processing Record 46 of Set 10 | talnakh
# Processing Record 47 of Set 10 | xunchang
# Processing Record 48 of Set 10 | palmer
# Processing Record 49 of Set 10 | clarence town
# Processing Record 0 of Set 11 | ayna
# Processing Record 1 of Set 11 | manggar
# Processing Record 2 of Set 11 | pyaozerskiy
# Processing Record 3 of Set 11 | casper
# Processing Record 4 of Set 11 | coihaique
# Processing Record 5 of Set 11 | port blair
# Processing Record 6 of Set 11 | zapolyarnyy
# Processing Record 7 of Set 11 | yagodnoye
# Processing Record 8 of Set 11 | mnogovershinnyy
# Processing Record 9 of Set 11 | cardston
# Processing Record 10 of Set 11 | kirakira
# Processing Record 11 of Set 11 | sokoto
# Processing Record 12 of Set 11 | los llanos de aridane
# Processing Record 13 of Set 11 | kahului
# Processing Record 14 of Set 11 | akureyri
# Processing Record 15 of Set 11 | gwadar
# Processing Record 16 of Set 11 | maple creek
# Processing Record 17 of Set 11 | carroll
# Processing Record 18 of Set 11 | davila
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 11 | aswan
# Processing Record 20 of Set 11 | hollola
# Processing Record 21 of Set 11 | yenotayevka
# Processing Record 22 of Set 11 | marzuq
# Processing Record 23 of Set 11 | novyy nekouz
# Processing Record 24 of Set 11 | ayr
# Processing Record 25 of Set 11 | solano
# Processing Record 26 of Set 11 | vostochnyy
# Processing Record 27 of Set 11 | neryungri
# Processing Record 28 of Set 11 | jining
# City not found. Skipping...
# Processing Record 29 of Set 11 | petaluma
# Processing Record 30 of Set 11 | zheleznodorozhnyy
# Processing Record 31 of Set 11 | alugan
# Processing Record 32 of Set 11 | kindersley
# Processing Record 33 of Set 11 | banyo
# Processing Record 34 of Set 11 | hovd
# Processing Record 35 of Set 11 | bo phloi
# Processing Record 36 of Set 11 | san jeronimo
# City not found. Skipping...
# Processing Record 37 of Set 11 | vacha
# City not found. Skipping...
# Processing Record 38 of Set 11 | geraldton
# Processing Record 39 of Set 11 | poum
# Processing Record 40 of Set 11 | puerto del rosario
# Processing Record 41 of Set 11 | tars
# Processing Record 42 of Set 11 | axim
# Processing Record 43 of Set 11 | san marcos de colon
# Processing Record 44 of Set 11 | pilar
# Processing Record 45 of Set 11 | ketchikan
# Processing Record 46 of Set 11 | woodward
# Processing Record 47 of Set 11 | edd
# City not found. Skipping...
# Processing Record 48 of Set 11 | conceicao do araguaia
# Processing Record 49 of Set 11 | schattdorf
# City not found. Skipping...
# Processing Record 0 of Set 12 | nakamura
# City not found. Skipping...
# Processing Record 1 of Set 12 | mehamn
# Processing Record 2 of Set 12 | rio gallegos
# Processing Record 3 of Set 12 | puerto carreno
# Processing Record 4 of Set 12 | hope
# Processing Record 5 of Set 12 | saryozek
# Processing Record 6 of Set 12 | dongsheng
# Processing Record 7 of Set 12 | mokhsogollokh
# Processing Record 8 of Set 12 | hasaki
# Processing Record 9 of Set 12 | nago
# Processing Record 10 of Set 12 | waipawa
# Processing Record 11 of Set 12 | tilichiki
# Processing Record 12 of Set 12 | avera
# Processing Record 13 of Set 12 | dilla
# Processing Record 14 of Set 12 | deputatskiy
# Processing Record 15 of Set 12 | samarai
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Loading valid cities into dataframe
city_pd = pd.DataFrame({'city': valid_cities})

city_pd['Lat'] = ""
city_pd['Lng'] = ""
city_pd['Max Temp'] = ""
city_pd['Humidity'] = ""
city_pd['Cloudiness'] = ""
city_pd['Wind Speed'] = ""
city_pd['Country'] = ""
city_pd['Date'] = ""

# ============ TEST DATA =========
# city = "okha"
# query_url = url + "appid=" + weather_api_key + "&q=" + city
# requests.get(query_url).json()
# ================================

for index, row in city_pd.iterrows():
    city = row['city']
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    city_pd.loc[index, 'Lat'] = response['coord']['lat']
    city_pd.loc[index, 'Lng'] = response['coord']['lon']
    city_pd.loc[index, 'Max Temp'] = response['main']['temp_max']
    city_pd.loc[index, 'Humidity'] = response['main']['humidity']
    city_pd.loc[index, 'Cloudiness'] = response['clouds']['all']
    city_pd.loc[index, 'Wind Speed'] = response['wind']['speed']
    city_pd.loc[index, 'Country'] = response['sys']['country']
    city_pd.loc[index, 'Date'] = response['dt']
city_pd.to_csv(output_data_file)
city_pd.head()
# Out:
#         city      Lat       Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0    gazojak  41.1875   61.4036   279.88       40        100       3.42
# 1  belvidere  42.2639  -88.8443   286.16       75        100       3.36
# 2    qaanaaq   77.484  -69.3632   251.54       87        100       2.49
# 3      wuwei  37.9281  102.6414   283.29       29          5       3.56
# 4     lompoc  34.6391 -120.4579   287.55       78          0       0.45
#
#   Country        Date
# 0      TM  1647932683
# 1      US  1647932683
# 2      GL  1647932683
# 3      CN  1647932683
# 4      US  1647932683

# %%
# Remove object columns
city_statistics = city_pd[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Date']]

# Change columns type to numbers for statistics calculations

city_statistics = city_statistics.astype({"Lat": 'float64', 
                                          "Lng": 'float64', 
                                          "Max Temp": 'float64', 
                                          "Humidity": 'float64', 
                                          "Cloudiness": 'float64', 
                                          "Wind Speed": 'float64',
                                          "Date": 'int64'})
city_statistics.describe(include='all')
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean    19.123835   20.723327  287.554619   71.244248   58.810619    3.850973
# std     33.037367   91.192378   14.045863   21.647084   41.813813    2.734830
# min    -54.800000 -179.166700  242.370000    5.000000    0.000000    0.000000
# 25%     -7.050000  -58.797200  276.410000   62.000000    8.000000    1.900000
# 50%     20.502200   24.731400  290.840000   76.000000   75.000000    3.210000
# 75%     47.500200  104.280000  299.230000   87.000000  100.000000    5.270000
# max     78.218600  179.316700  311.880000  100.000000  100.000000   16.010000
#
#                Date
# count  5.650000e+02
# mean   1.647933e+09
# std    8.567989e+01
# min    1.647932e+09
# 25%    1.647933e+09
# 50%    1.647933e+09
# 75%    1.647933e+09
# max    1.647933e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Check for cities with humidity over 100%

city_pd = city_pd.astype({"Lat": 'float64', 
                          "Lng": 'float64', 
                          "Max Temp": 'float64', 
                          "Humidity": 'float64', 
                          "Cloudiness": 'float64', 
                          "Wind Speed": 'float64',
                          "Date": 'int64'})

city_data = city_pd.loc[(city_pd['Humidity']) <= 100 , :]
if (len(city_data) == len(city_pd)):
    print("No cities with humidity over 100% found")
else:
    city_high_humidity = city_pd.loc[(city_pd['Humidity']) > 100 , :]
    print(f"{len(city_pd)-len(city_data)} cities with humidity over 100% found")
    city_statistics.describe(include='all')
# Out:
# No cities with humidity over 100% found

# %%
#  Get the indices of cities that have humidity over 100%.
# city_high_humidity

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data
clean_city_data.head()
# Out:
#         city      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    gazojak  41.1875   61.4036    279.88      40.0       100.0        3.42
# 1  belvidere  42.2639  -88.8443    286.16      75.0       100.0        3.36
# 2    qaanaaq  77.4840  -69.3632    251.54      87.0       100.0        2.49
# 3      wuwei  37.9281  102.6414    283.29      29.0         5.0        3.56
# 4     lompoc  34.6391 -120.4579    287.55      78.0         0.0        0.45
#
#   Country        Date
# 0      TM  1647932683
# 1      US  1647932683
# 2      GL  1647932683
# 3      CN  1647932683
# 4      US  1647932683

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
max_temp_f = []
for i in clean_city_data['Max Temp']:
    max_temp_f.append(1.8*(i - 273)+32)
clean_city_data['Max Temp F'] = max_temp_f

# %%
clean_city_data
# Out:
#             city      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        gazojak  41.1875   61.4036    279.88      40.0       100.0
# 1      belvidere  42.2639  -88.8443    286.16      75.0       100.0
# 2        qaanaaq  77.4840  -69.3632    251.54      87.0       100.0
# 3          wuwei  37.9281  102.6414    283.29      29.0         5.0
# 4         lompoc  34.6391 -120.4579    287.55      78.0         0.0
# ..           ...      ...       ...       ...       ...         ...
# 560    tilichiki  60.4667  166.1000    269.64      95.0       100.0
# 561        avera  33.1940  -82.5271    285.18      77.0       100.0
# 562        dilla   6.4100   38.3100    297.67      53.0        77.0
# 563  deputatskiy  69.3000  139.9000    260.14      95.0       100.0
# 564      samarai -10.6167  150.6667    302.06      76.0        73.0
#
#      Wind Speed Country        Date  Max Temp F
# 0          3.42      TM  1647932683      44.384
# 1          3.36      US  1647932683      55.688
# 2          2.49      GL  1647932683      -6.628
# 3          3.56      CN  1647932683      50.522
# 4          0.45      US  1647932683      58.190
# ..          ...     ...         ...         ...
# 560        2.58      RU  1647932817      25.952
# 561        2.71      US  1647932817      53.924
# 562        0.57      ET  1647932817      76.406
# 563        1.92      RU  1647932817       8.852
# 564        2.71      PG  1647932818      84.308
#
# [565 rows x 10 columns]

# %%
today = pd.to_datetime('today').strftime("%d/%m/%y")
invalid_characters = [",", "/", " "]

# %%
lat_sort = clean_city_data['Lat'].reset_index(drop=True)
x_limit = clean_city_data['Lat'].max()
x_limit_min = int(clean_city_data['Lat'].min())
y_values = np.round(clean_city_data['Max Temp F'], 2)
x_axis = clean_city_data['Lat']
plt_title = f"City Latitude vs. Max Temperature ({today})"
   
plt.figure(figsize=(10, 6))
plt.title(f"City Latitude vs. Max Temperature ({today})")
plt.xlabel("Latitide")
plt.ylabel("Max Temperature (F)")

plt.scatter(x_axis, y_values, marker="o", facecolors="tab:blue", edgecolors="black", alpha=0.75)
plt.grid(True)


# Removing invalid characters from title to allow title to used as filename
filename = plt_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_sort = clean_city_data['Lat'].reset_index(drop=True)
x_limit = clean_city_data['Lat'].max()
x_limit_min = int(clean_city_data['Lat'].min())
y_values = np.round(clean_city_data['Humidity'], 2)
x_axis = clean_city_data['Lat']
plt.figure(figsize=(10, 6))

plt_title = f"City Latitude vs. Humidity ({today})"
plt.title(plt_title)

plt.xlabel("Latitide")
plt.ylabel("Humidity (%)")
plt.scatter(x_axis, y_values, marker="o", facecolors="tab:blue", edgecolors="black", alpha=0.75)
plt.grid(True)

# Removing invalid characters from title to allow title to used as filename
filename = plt_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_sort = clean_city_data['Lat'].reset_index(drop=True)
x_limit = clean_city_data['Lat'].max()
x_limit_min = int(clean_city_data['Lat'].min())
y_values = np.round(clean_city_data['Cloudiness'], 2)
x_axis = clean_city_data['Lat']
plt.figure(figsize=(10, 6))

plt_title = f"City Latitude vs. Cloudiness ({today})"
plt.title(plt_title)

plt.xlabel("Latitide")
plt.ylabel("Cloudiness (%)")
plt.scatter(x_axis, y_values, marker="o", facecolors="tab:blue", edgecolors="black", alpha=0.75)

plt.grid(True)

# Removing invalid characters from title to allow title to used as filename
filename = plt_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_sort = clean_city_data['Lat'].reset_index(drop=True)
x_limit = clean_city_data['Lat'].max()
x_limit_min = int(clean_city_data['Lat'].min())
y_values = np.round(clean_city_data['Wind Speed'], 2)
x_axis = clean_city_data['Lat']
plt.figure(figsize=(10, 6))
plt_title = f"City Latitude vs. Wind Speed ({today})"
plt.title(plt_title)
plt.xlabel("Latitide")
plt.ylabel("Wind Speed (mph)")
plt.scatter(x_axis, y_values, marker="o", facecolors="tab:blue", edgecolors="black", alpha=0.75)

plt.grid(True)

# Removing invalid characters from title to allow title to used as filename
filename = plt_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
import scipy.stats as st
from scipy.stats import linregress
Nth_hemp = clean_city_data.loc[(clean_city_data['Lat']) > 0 , :]
Sth_hemp = clean_city_data.loc[(clean_city_data['Lat']) < 0 , :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_axis = Nth_hemp['Max Temp']
latitude = Nth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Max Temperature"
plot_title = "Northern Hemisphere - Max Temp vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(10, 6))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(45, 300),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

# Removing invalid characters from title to allow title to used as filename
filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.7894734302937733
# Line Equation: y = -0.64x + 307.68

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
y_axis = Sth_hemp['Max Temp']
latitude = Sth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Max Temperature"
plot_title = "Southern Hemisphere - Max Temp vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(10, 6))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(-20, 283),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.2528376675706103
# Line Equation: y = 0.22x + 300.97

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_axis = Nth_hemp['Humidity']
latitude = Nth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Humidity (%)"
plot_title = "Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(10, 6))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(52, 15),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.13442918265477286
# Line Equation: y = 0.42x + 53.4

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
y_axis = Sth_hemp['Humidity']
latitude = Sth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Humidity (%)"
plot_title = "Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(10, 6))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(-15, 35),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.04567269744412566
# Line Equation: y = 0.27x + 80.61

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_axis = Nth_hemp['Cloudiness']
latitude = Nth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Cloudiness (%)"
plot_title = "Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(10, 6))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(76.5, 47),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.02723203167307205
# Line Equation: y = 0.34x + 44.36

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
y_axis = Sth_hemp['Cloudiness']
latitude = Sth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Cloudiness (%)"
plot_title = "Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(10, 6))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(-7, 44),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.14763124718860798
# Line Equation: y = 1.12x + 83.95

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_axis = Nth_hemp['Wind Speed']
latitude = Nth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Wind Speed (mph)"
plot_title = f"Northern Hemisphere - {y_label} vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(10, 6))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
# plt.annotate(line_eq,(25, 17),fontsize=12,color="red")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")

filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.01158474513652462
# Line Equation: y = 0.02x + 3.43

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_axis = Sth_hemp['Wind Speed']
latitude = Sth_hemp['Lat']
correlation = st.pearsonr(latitude, y_axis)
x_label = f"Latitude"
y_label = f"Wind Speed (mph)"
plot_title = f"Southern Hemisphere - {y_label} vs. Latitude Linear Regression"
(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, y_axis)
regress_values = (latitude * slope) + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.figure(figsize=(10, 6))
plt.scatter(latitude, y_axis)
plt.plot(latitude, regress_values, "r-")
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.title(plot_title)
print(f"The r-squared is: {rvalue**2}")
print(f"Line Equation: {line_eq}")
filename = plot_title.replace('.', '')

for invalid_charater in invalid_characters:
    filename = filename.replace(invalid_charater, '_')

plt.savefig("Images/" + filename + ".png", facecolor="white")
plt.show()
# Out:
# The r-squared is: 0.09000877250406134
# Line Equation: y = -0.05x + 2.52
